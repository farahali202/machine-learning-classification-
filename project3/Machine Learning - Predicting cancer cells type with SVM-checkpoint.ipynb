# %% [markdown]
# # SVM Algorithm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploratory data analysis

# %%
df=pd.read_csv('cell_samples.csv')

# %%
df
# Out:
#           ID  Clump  UnifSize  UnifShape  MargAdh  SingEpiSize BareNuc  \
# 0    1000025      5         1          1        1            2       1
# 1    1002945      5         4          4        5            7      10
# 2    1015425      3         1          1        1            2       2
# 3    1016277      6         8          8        1            3       4
# 4    1017023      4         1          1        3            2       1
# ..       ...    ...       ...        ...      ...          ...     ...
# 694   776715      3         1          1        1            3       2
# 695   841769      2         1          1        1            2       1
# 696   888820      5        10         10        3            7       3
# 697   897471      4         8          6        4            3       4
# 698   897471      4         8          8        5            4       5
#
#      BlandChrom  NormNucl  Mit  Class
# 0             3         1    1      2
# ...

# %% [markdown]
# The example is based on a dataset that is publicly available from the UCI Machine Learning Repository (Asuncion and Newman, 2007)[http://mlearn.ics.uci.edu/MLRepository.html]. The dataset consists of several hundred human cell sample records, each of which contains the values of a set of cell characteristics. The fields in each record are:
# Field name:Description
# ID:Clump thickness
# Clump:Clump thickness
# UnifSize:Uniformity of cell size
# UnifShape:Uniformity of cell shape
# MargAdh:Marginal adhesion
# SingEpiSize:Single epithelial cell size
# BareNuc:Bare nuclei
# BlandChrom:Bland chromatin
# NormNucl:Normal nucleoli
# Mit:Mitoses
# Class:Benign or malignant

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           699 non-null    int64
#  1   Clump        699 non-null    int64
#  2   UnifSize     699 non-null    int64
#  3   UnifShape    699 non-null    int64
#  4   MargAdh      699 non-null    int64
#  5   SingEpiSize  699 non-null    int64
#  6   BareNuc      699 non-null    object
#  7   BlandChrom   699 non-null    int64
#  8   NormNucl     699 non-null    int64
#  9   Mit          699 non-null    int64
#  10  Class        699 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 60.2+ KB

# %%
df.Class.unique()
# Out:
# array([2, 4], dtype=int64)

# %%
df.Class.value_counts()
# Out:
# 2    458
# 4    241
# Name: Class, dtype: int64

# %% [markdown]
# # Data_preprocessing

# %%
df.BareNuc.unique()
# Out:
# array(['1', '10', '2', '4', '3', '9', '7', '?', '5', '8', '6'],
#       dtype=object)

# %%
df['BareNuc']=df['BareNuc'].replace('?',np.NAN)

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
#fill the NA with 0
X=df.iloc[:,1:10]
y=df.iloc[:,10]
X['BareNuc'].fillna(0,inplace=True)
X['BareNuc'].unique()
# Out:
# array(['1', '10', '2', '4', '3', '9', '7', 0, '5', '8', '6'], dtype=object)

# %%
X['BareNuc']=X['BareNuc'].astype(int)
X['BareNuc'].unique()
# Out:
# array([ 1, 10,  2,  4,  3,  9,  7,  0,  5,  8,  6])

# %% [markdown]
# # data normalization

# %%
df.iloc[:,1:].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#data normalization
from sklearn.preprocessing import StandardScaler
stan=StandardScaler()
X_tra=stan.fit_transform(X)
X_tra=pd.DataFrame(X_tra)
X_tra.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Data Visualization

# %%
#correlation between var
correlation = df.corr()

# %%
correlation['Class'].sort_values(ascending=False)
# Out:
# Class          1.000000
# UnifShape      0.818934
# UnifSize       0.817904
# BlandChrom     0.756616
# Clump          0.716001
# NormNucl       0.712244
# MargAdh        0.696800
# SingEpiSize    0.682785
# Mit            0.423170
# ID            -0.080226
# Name: Class, dtype: float64

# %% [markdown]
# The correlation coefficient, which ranges from -1 to +1, serves as a measure of the strength and direction of linear relationships between variables.
#
# A correlation coefficient close to +1 indicates a strong positive correlation. In this dataset, we observe a robust positive correlation between 'Class' and variables such as 'Bare_Nuclei,' 'Uniformity_Cell_Shape,' and 'Uniformity_Cell_Size.'
#
# Conversely, a correlation coefficient close to -1 suggests a strong negative correlation. When the coefficient approaches 0, it indicates little to no correlation. Notably, all variables exhibit positive correlations with the 'Class' variable. Some variables demonstrate a strong positive correlation, while others display a negative correlation.

# %%
#correlation heatmap
plt.figure(figsize=(8,6))
sns.heatmap(correlation,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 'Class' exhibits a high positive correlation (correlation coefficient = 0.82) with 'Uniformity_Cell_Size,' 'Uniformity_Cell_Shape,' and 'Bare_Nuclei.'
#
# 'Class' displays positive correlations with 'Clump_thickness' (correlation coefficient=0.72), 'Marginal_Adhesion' (correlation coefficient=0.70), 'Single_Epithelial_Cell_Size' (correlation coefficient = 0.68), and 'Normal_Nucleoli' (correlation coefficient=0.71).
#
# 'Class' shows a weaker positive correlation with 'Mitoses' (correlation coefficient=0.42).
#
# 'Mitoses' exhibits weak positive correlations (correlation coefficient < 0.50) with all other variables in the dataset.

# %% [markdown]
# # Training model

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_tra,y,random_state=4,test_size=0.2)
X_train.shape
X_test.shape
# Out:
# (140, 9)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
param_grid = [
    {'C': [0.1, 1, 10, 100, 1000],
     'gamma': [0.0001, 0.001, 0.01, 0.1, 1],
     'kernel': ['rbf']},
    {'C': [0.1, 1, 10, 100, 1000],
     'kernel': ['linear']}
]
grid = GridSearchCV(SVC(), param_grid, verbose=2)
grid.fit(X_train, y_train)
classifier=grid
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
# predicting 
y_pred=grid.predict(X_test)

# %% [markdown]
# # Evaluation(results)

# %%
from sklearn import metrics
print('confusion matrix:\n', metrics.confusion_matrix(y_test, y_pred))
print('accuracy:', np.round(metrics.accuracy_score(y_test, y_pred), 4))
print('precision:', np.round(metrics.precision_score(y_test, y_pred), 4))
print('recall:', np.round(metrics.recall_score(y_test, y_pred), 4))
print('f1-score:', np.round(metrics.f1_score(y_test, y_pred), 4))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[87  1]
#  [ 3 49]]
# accuracy: 0.9714
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6792\1365351835.py in <module>
#       2 print('confusion matrix:\n', metrics.confusion_matrix(y_test, y_pred))
#       3 print('accuracy:', np.round(metrics.accuracy_score(y_test, y_pred), 4))
# ----> 4 print('precision:', np.round(metrics.precision_score(y_test, y_pred), 4))
#       5 print('recall:', np.round(metrics.recall_score(y_test, y_pred), 4))
#       6 print('f1-score:', np.round(metrics.f1_score(y_test, y_pred), 4))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1755     array([0.5, 1. , 1. ])
#    1756     """
# -> 1757     p, _, _, _ = precision_recall_fscore_support(
#    1758         y_true,
# ...
